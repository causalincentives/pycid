# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
sys.path.append("..") #TODO: make /cid a package, then delete this
import numpy as np
from cid import CID
from cpd import NullCPD, FunctionCPD
from analyze.value_of_information import draw_voi

# %%
cid = CID([
    ('A', 'X'),  # defining the graph's nodes and edges
    ('Z', 'X'),
    ('Z', 'Y'),
    ('X', 'D'),
    ('X', 'Y'),
    ('D', 'U'),
    ('Y', 'U')
],
    decision_nodes=['D'],
    utility_nodes=['U'])

cid.draw()

# %%
draw_voi(cid, 'D')

# %%
cid = CID([
    ('A', 'X'),  # defining the graph's nodes and edges
    ('X', 'D'),
    ('X', 'Y'),
    ('D', 'U'),
    ('Y', 'U')
],
    decision_nodes=['D'],
    utility_nodes=['U'])

draw_voi(cid, 'D')

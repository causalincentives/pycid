# %%
# %load_ext autoreload
# %autoreload 2
# %pdb  # include for debugging
import sys
sys.path.append("..") #TODO: make /cid a package, then delete this
from generate.random_cid import random_cids, random_cid
import numpy as np
import random

# %%
import networkx as nx
import pylab as plt
def draw_bn(bn):
    nx.draw(cid, with_labels=True)
    plt.show()

# %%
cid = random_cids(n_cids=1)[0]
# Warning, flaky. If it gives "ValueError: D3 is an ancestor of D1", just run it again
# Out:
# names computed
# first edges generated [('D0', 'D1'), ('D0', 'D2'), ('D0', 'D4'), ('D0', 'U1'), ('S0', 'D4'), ('S0', 'S1'), ('S0', 'U0'), ('S0', 'U2'), ('S0', 'U4'), ('D1', 'D5'), ('D1', 'D6'), ('D1', 'U0'), ('D1', 'U3'), ('D2', 'D4'), ('D2', 'D5'), ('D2', 'U1'), ('D2', 'U2'), ('D3', 'D4'), ('D3', 'D5'), ('D3', 'S1'), ('D3', 'U0'), ('D3', 'U3'), ('D3', 'U4'), ('D4', 'U0'), ('D4', 'U1'), ('D4', 'U3'), ('D4', 'U4'), ('D5', 'U4'), ('D6', 'U0'), ('D6', 'U1'), ('D6', 'U3'), ('D6', 'U4'), ('S1', 'U3')]
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# found active path
# adding edge D3 D0
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# found active path
# adding edge D3 D2
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D2']
# look for neighboors ['pi', 'D3', 'D2', 'U1']
# look for neighboors ['pi', 'D3', 'D2', 'D4']
# look for neighboors ['pi', 'D3', 'D2', 'D4', 'U4']
# look for neighboors ['pi', 'D3', 'D2', 'D4', 'U1']
# found active path
# adding edge D2 D1
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D2']
# found active path
# adding edge D3 D1
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D1']
# look for neighboors ['pi', 'D3', 'D1', 'D2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'U2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'U1']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4', 'U4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4', 'U1']
# found active path
# adding edge D4 D6
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D1']
# look for neighboors ['pi', 'D3', 'D1', 'D2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'U2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'U1']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4', 'S0']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4', 'S0', 'U4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D0', 'D4', 'S0', 'U2']
# found active path
# adding edge D0 D6
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D1']
# look for neighboors ['pi', 'D3', 'D1', 'D2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D4', 'S0']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D4', 'S0', 'U4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D4', 'S0', 'U2']
# found active path
# adding edge S0 D6
# look for neighboors ['pi']
# look for neighboors ['pi', 'D3']
# look for neighboors ['pi', 'D3', 'U3']
# look for neighboors ['pi', 'D3', 'S1']
# look for neighboors ['pi', 'D3', 'S1', 'U3']
# look for neighboors ['pi', 'D3', 'U4']
# look for neighboors ['pi', 'D3', 'D1']
# look for neighboors ['pi', 'D3', 'D1', 'D2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D4']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'U1']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'U2']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D5']
# look for neighboors ['pi', 'D3', 'D1', 'D2', 'D5', 'U4']
# look for neighboors ['pi', 'D3', 'D2']
# look for neighboors ['pi', 'D3', 'D2', 'U2']
# look for neighboors ['pi', 'D3', 'D2', 'D1']
# look for neighboors ['pi', 'D3', 'D2', 'D5']
# look for neighboors ['pi', 'D3', 'D2', 'D5', 'U4']
# look for neighboors ['pi', 'D3', 'D2', 'U1']
# look for neighboors ['pi', 'D3', 'D2', 'D4']
# found active path
# adding edge D3 D6
# look for neighboors ['pi']
# look for neighboors ['pi', 'D0']
# look for neighboors ['pi', 'D0', 'D6']
# look for neighboors ['pi', 'D0', 'D6', 'U4']
# look for neighboors ['pi', 'D0', 'D6', 'U1']
# found active path
# adding edge D6 D5
# look for neighboors ['pi']
# look for neighboors ['pi', 'D0']
# look for neighboors ['pi', 'D0', 'D6']
# look for neighboors ['pi', 'D0', 'D6', 'D4']
# look for neighboors ['pi', 'D0', 'D6', 'D4', 'U3']
# look for neighboors ['pi', 'D0', 'D6', 'D4', 'S0']
# look for neighboors ['pi', 'D0', 'D6', 'D4', 'S0', 'U4']
# look for neighboors ['pi', 'D0', 'D6', 'D4', 'S0', 'U2']
# found active path
# adding edge D4 D5
# look for neighboors ['pi']
# look for neighboors ['pi', 'D0']
# look for neighboors ['pi', 'D0', 'D6']
# look for neighboors ['pi', 'D0', 'D6', 'S0']
# look for neighboors ['pi', 'D0', 'D6', 'S0', 'U2']
# look for neighboors ['pi', 'D0', 'D6', 'S0', 'S1']
# look for neighboors ['pi', 'D0', 'D6', 'S0', 'S1', 'U3']
# look for neighboors ['pi', 'D0', 'D6', 'S0', 'U4']
# found active path
# adding edge D0 D5
# look for neighboors ['pi']
# look for neighboors ['pi', 'D4']
# look for neighboors ['pi', 'D4', 'U3']
# look for neighboors ['pi', 'D4', 'D6']
# look for neighboors ['pi', 'D4', 'D6', 'U3']
# look for neighboors ['pi', 'D4', 'D6', 'U4']
# found active path
# adding edge D4 D1
# look for neighboors ['pi']
# look for neighboors ['pi', 'D4']
# look for neighboors ['pi', 'D4', 'S0']
# look for neighboors ['pi', 'D4', 'S0', 'U2']
# look for neighboors ['pi', 'D4', 'S0', 'S1']
# look for neighboors ['pi', 'D4', 'S0', 'S1', 'U3']
# look for neighboors ['pi', 'D4', 'S0', 'D6']
# look for neighboors ['pi', 'D4', 'S0', 'D6', 'U3']
# look for neighboors ['pi', 'D4', 'S0', 'D6', 'U4']
# found active path
# adding edge S0 D1
# look for neighboors ['pi']
# look for neighboors ['pi', 'D4']
# look for neighboors ['pi', 'D4', 'S0']
# look for neighboors ['pi', 'D4', 'S0', 'U2']
# look for neighboors ['pi', 'D4', 'S0', 'S1']
# look for neighboors ['pi', 'D4', 'S0', 'S1', 'U3']
# look for neighboors ['pi', 'D4', 'S0', 'D6']
# look for neighboors ['pi', 'D4', 'S0', 'U4']
# look for neighboors ['pi', 'D4', 'S0', 'D1']
# found active path
# adding edge S0 D5
# look for neighboors ['pi']
# look for neighboors ['pi', 'D2']
# look for neighboors ['pi', 'D2', 'U2']
# look for neighboors ['pi', 'D2', 'D1']
# look for neighboors ['pi', 'D2', 'D5']
# look for neighboors ['pi', 'D2', 'D5', 'U4']
# found active path
# adding edge D2 D6
# sufficient recall added

# %%
draw_bn(cid)

# %%
cid.get_children('D1')
# Out:
# ['D5', 'D6', 'U0', 'U3']

# %%
cid.get_children('D2')
# Out:
# ['D4', 'D5', 'U1', 'U2', 'D1', 'D6']

# %%
cid.get_children('S0')
# Out:
# ['D4', 'S1', 'U0', 'U2', 'U4', 'D6', 'D1', 'D5']

# %%
from typing import List

def _find_path_recurse(bn, path: List[str], B: str):
    if path and path[-1]==B:
        return path
    else:
        children = bn.get_children(path[-1])
        for child in children:
            ext = _find_path_recurse(bn, path + [child], B)
            if ext:
                return ext
            
def find_path_from(bn, A, B):
    path = _find_path_recurse(bn, [A], B)
    if path:
        return path
    else:
        print("No path from {} to {} could be found".format(A, B))

# %%
find_path_from(cid, 'S0', 'U3')
# Out:
# ['S0', 'D4', 'U3']

# %%
find_path_from(cid, 'D2', 'U3')
# Out:
# ['D2', 'D4', 'U3']

# %%
def active_neighbours(bn, A: str, E: List[str]):
    pass
    #find neighbours of A active conditional on E
    # active_parents = [i for i in ]
    # if A not in E:
        # active_children = [i for i in bn.get_children(A)]
    
def find_active_path(bn, A, B):
    pass

# %%
# %load_ext autoreload
# %autoreload 2
# %pdb
import sys
sys.path.append("..") #TODO: make /cid a package, then delete this
from generate import random_cids, random_cid
import numpy as np
import random
# Out:
# Automatic pdb calling has been turned ON

# %%
import networkx as nx
import pylab as plt
def draw_bn(bn):
    nx.draw(cid, with_labels=True)
    plt.show()

# %%
cid = random_cids(n_cids=1)[0]
# Out:
# WARNING:root:D1 has insufficient recall of D0 due to utility U2
# WARNING:root:D1 has insufficient recall of D0 due to utility U4
# WARNING:root:D1 has insufficient recall of D0 due to utility U2
# WARNING:root:D2 has insufficient recall of D0 due to utility U4
# WARNING:root:D1 has insufficient recall of D0 due to utility U4
# WARNING:root:D1 has insufficient recall of D0 due to utility U0
# WARNING:root:D3 has insufficient recall of D1 due to utility U1
# WARNING:root:D3 has insufficient recall of D1 due to utility U0
# WARNING:root:D1 has insufficient recall of D0 due to utility U2
# WARNING:root:D1 has insufficient recall of D0 due to utility U0
# WARNING:root:D1 has insufficient recall of D0 due to utility U3
# WARNING:root:D2 has insufficient recall of D1 due to utility U0
# WARNING:root:D3 has insufficient recall of D2 due to utility U4
# WARNING:root:D1 has insufficient recall of D0 due to utility U3

# %%
draw_bn(cid)

# %%
cid.get_children('D1')
# Out:
# ['U1', 'S1', 'D2', 'U2']

# %%
cid.get_children('D2')
# Out:
# ['U3', 'U5', 'D0', 'S0', 'D3']

# %%
cid.get_children('S0')
# Out:
# []

# %%
from typing import List
def _find_path_recurse(bn, path: List[str], B: str):
    if path[-1]==B:
        return path
    else:
        children = bn.get_children(path[-1])
        for child in children:
            ext = path + [child]
            ext = _find_path_recurse(bn, ext, B)
            if ext[-1]==B:
                return ext
            
def find_path_from(bn, A, B):
    return find_path_recurse(bn, [A], B)

# %%
find_path_recurse(cid, ['S0'], 'U3')

# %%
find_path_from(cid, 'D2', 'U3')
# Out:
# ['D2', 'U3']

# %%
def active_neighbours(bn, A: str, E: List[str]):
    #find neighbours of A active conditional on E
    active_parents = [i for i in ]
    if A not in E:
        active_children = [i for i in bn.get_children(A)]
        
    
    
    

def find_active_path(bn, A, B):
    pass

# %%
# %load_ext autoreload
# %autoreload 2
# %pdb
import sys
sys.path.append("..") #TODO: make /cid a package, then delete this
from generate import random_cids, random_cid
import numpy as np
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Automatic pdb calling has been turned ON

# %%
import networkx as nx
import pylab as plt
def draw_bn(bn):
    nx.draw(cid, with_labels=True)
    plt.show()

# %%
cids = random_cids(n_cids=1)
# Out:
# WARNING:root:D3 has insufficient recall of D0 due to utility U0
# WARNING:root:D2 has insufficient recall of D0 due to utility U1
# WARNING:root:D1 has insufficient recall of D0 due to utility U4
# WARNING:root:D1 has insufficient recall of D0 due to utility U2
# WARNING:root:D1 has insufficient recall of D0 due to utility U1
# WARNING:root:D2 has insufficient recall of D1 due to utility U4
# WARNING:root:D2 has insufficient recall of D0 due to utility U3
# WARNING:root:D1 has insufficient recall of D0 due to utility U0
# WARNING:root:D1 has insufficient recall of D0 due to utility U3
# WARNING:root:D1 has insufficient recall of D0 due to utility U1
# WARNING:root:D2 has insufficient recall of D0 due to utility U2
# WARNING:root:D2 has insufficient recall of D1 due to utility U1
# WARNING:root:D1 has insufficient recall of D0 due to utility U0
# WARNING:root:D1 has insufficient recall of D0 due to utility U1
# WARNING:root:D3 has insufficient recall of D1 due to utility U5

# %%
draw_bn(cids[0])

# %%
cids[0].check_sufficient_recall()
# Out:
# True
